# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineering student bring a ladder to class?
#
# Because they heard the key to mastering large models is *scaling up*!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to work?
#
# Because they kept hearing about "temperature scaling," "embedding layers," and "stacking transformers" — and they wanted to make sure they could reach the higher dimensions!
#
# (Though between you and me, they later realized the real climb was optimizing those hyperparameters... that's a hill climbing problem that never ends! 🎯)
#
# ---
#
# *Bonus dad joke: What's an LLM engineer's favorite type of attention? Self-attention, obviously. They're very focused on themselves... and also query-key-value relationships.* 😄
#
# Good luck on your journey! Remember: we're all just trying to reduce our loss function, one epoch at a time. 🚀

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Interpretation:
# - There are two volumes with pages thickness 2 cm each.
# - Each cover is 2 mm thick.
# - The worm starts at the first page of the first volume and ends at the last page of the second volume, traveling perpendicular to the pages (i.e., straight through any intervening pages and covers).
# - Books are on a shelf, arranged in order: [Cover A front] [Pages A] [Cover A back] [Space between volumes?] [Cover B front] [Pages B] [Cover B back]. However, when two books stand side by side, the touching parts are the back cover of the first book and the front cover of the second book.
#
# Important detail: The worm travels from the first page (the very first page) of the first volume to the last page (the very last page) of the second volume. Since pages are on the inside between covers, the path that minimizes distance (perpendicular to pages) would go straight through the covers/pages along the stack.
#
# Compute total thickness along the straight line from first page of Vol 1 to last page of Vol 2:
# - Each volume: pages thickness = 2 cm.
# - Each cover thickness = 2 mm = 0.2 cm.
# - Vol 1 structure (from outer left to right): Front cover (0.2 cm), pages 2.0 cm, back cover 0.2 cm.
# - Vol 2 structure (immediately to the right): Front cover 0.2 cm, pages 2.0 cm, back cover 0.2 cm.
#
# The worm starts at the first page of Vol 1. The "first page" is at the very start of the pages block on the left side of Vol 1 (i.e., just after the front cover). The worm ends at the last page of Vol 2, which is just before Vol 2's back cover (i.e., at the far end of Vol 2’s pages block, just before the back cover).
#
# Distance along perpendicular through the stack includes:
# - Through the rest of Vol 1 after the first page: it has to pass through the remainder of Vol 1 pages (but note: starting at the very first page means immediately after the front cover; to reach the end of Vol 1 pages, it must traverse the remaining pages in Vol 1: 2.0 cm total pages minus an infinitesimal start overlap). In these puzzles, we treat it as traversing the entire thickness of the Vol 1 except the starting page thickness is negligible, effectively passing through 2.0 cm of Vol 1 pages.
# - Then through Vol 1 back cover: 0.2 cm.
# - Then through Vol 2 front cover: 0.2 cm.
# - Then through Vol 2 pages: 2.0 cm (to reach the last page).
# - It stops there, not needing to go through Vol 2 back cover.
#
# Sum:
# - Vol 1 pages: 2.0 cm
# - Vol 1 back cover: 0.2 cm
# - Vol 2 front cover: 0.2 cm
# - Vol 2 pages: 2.0 cm
# Total = 2.0 + 0.2 + 0.2 + 2.0 = 4.4 cm
#
# Answer: 4.4 cm (44 mm).

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and which pages the worm travels through.
#
# **Understanding book arrangement:**
# When two volumes stand side by side on a bookshelf (as books normally stand), I need to think about how books are oriented:
# - Books face the same direction with spines outward
# - The first volume is on the left, the second volume is on the right
# - When a book is closed:
#   - The FIRST page of a volume is on the RIGHT side of that book (next to the back cover)
#   - The LAST page of a volume is on the LEFT side of that book (next to the front cover)
#
# **Setting up the problem:**
# - Volume 1 (left book):
#   - Front cover (2 mm) | pages (2 cm) | Back cover (2 mm)
#   - First page is on the right side (near the back cover)
#
# - Volume 2 (right book):
#   - Front cover (2 mm) | pages (2 cm) | Back cover (2 mm)
#   - Last page is on the left side (near the front cover)
#
# **The worm's path:**
# Starting point: First page of Volume 1 = right side of Volume 1
# Ending point: Last page of Volume 2 = left side of Volume 2
#
# The worm gnaws through:
# 1. Back cover of Volume 1: 2 mm
# 2. Front cover of Volume 2: 2 mm
#
# That's it! The worm doesn't go through any pages at all, only through the two covers that are adjacent to each other.
#
# **Total distance: 2 mm + 2 mm = 4 mm**
#
# The answer is **4 mm** (or **0.4 cm**).

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Reason: On a shelf, Volume 1 is to the left of Volume 2. In a left-to-right book, the first page lies just inside the front cover (the right side of Volume 1), and the last page lies just inside the back cover (the left side of Volume 2). Those two sides face each other, so the worm passes only through two covers: 2 mm + 2 mm = 4 mm. The 2 cm of pages are irrelevant here.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on our assumptions about how books are arranged. Here's the step-by-step solution:
#
# 1.  **Visualize the books:** The two volumes are side by side on the shelf in the usual order: Volume 1 on the left, Volume 2 on the right.
#
# 2.  **Locate the starting point:** The "first page of the first volume" is not on the far left of the book. It's on the right side of Volume 1, just inside the front cover.
#
# 3.  **Locate the ending point:** The "last page of the second volume" is not on the far right of the book. It's on the left side of Volume 2, just inside its back cover.
#
# 4.  **Trace the path:** The two books are touching. This means the front cover of Volume 1 is right next to the back cover of Volume 2.
#
#     [Back Cover 1 | Pages 1 | **Front Cover 1**] [**Back Cover 2** | Pages 2 | Front Cover 2]
#
# The worm starts at the first page of Volume 1 and gnaws its way to the last page of Volume 2. It only needs to travel through the materials that are physically between these two pages. As you can see from the diagram, the only things between the start and end points are:
#
# *   The front cover of Volume 1 (2 mm)
# *   The back cover of Volume 2 (2 mm)
#
# The worm does not go through the pages of either book.
#
# **Calculation:**
# 2 mm (cover 1) + 2 mm (cover 2) = **4 mm**
#
# The worm gnawed through a distance of **4 mm**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the chance at $2,000, mutual cooperation gives us both a guaranteed $1,000. If I steal and my partner shares, I gain an extra $1,000 but at the complete expense of my partner. If we both think this way and both steal, we both get nothing.
#
# The rational cooperative strategy is to Share, hoping my partner reasons the same way. Even though there's risk, $1,000 for certain (if both cooperate) is better than the likely outcome of both walking away with nothing.
#
# **Share**

# %%
response = openai.chat.completions.create(model="gpt-5", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Share

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic game theory problem known as the Prisoner's Dilemma. There is no single "correct" answer, as the best choice depends entirely on your goal, your philosophy, and what you assume about your partner.
#
# Let's break down the logic before I make my choice.
#
# *   **The Purely Rational Choice (Game Theory):** From a purely self-interested and logical standpoint, you should always choose **Steal**. Here's why:
#     *   If your partner chooses **Share**, your best move is to **Steal** ($2,000 is better than $1,000).
#     *   If your partner chooses **Steal**, your best move is also to **Steal** ($0 is better than getting nothing while they get $2,000).
#     *   In either scenario, "Steal" gives you a better or equal outcome. This is called a "dominant strategy." If both players follow this cold logic, you both walk away with nothing.
#
# *   **The Cooperative Choice (Trust):** The best *overall* outcome for the two of you is for both to choose **Share**. This way, you collectively win $2,000 ($1,000 each). Every other outcome results in less money being won in total ($2,000 for one person, or $0). This choice, however, requires you to trust that your partner is also thinking about the collective good and won't betray you for personal gain. It carries the biggest personal risk—the "sucker's payoff" of getting $0.
#
# ### My Final Decision
#
# As an AI, my programming is based on logic and achieving optimal outcomes. I don't have human emotions like greed, fear of betrayal, or the thrill of winning. Therefore, I analyze the problem from the perspective of the entire system.
#
# The most efficient and beneficial outcome for the system (both of us) is the one where the most value is created. That outcome is clearly (Share, Share). The "rational" choice of (Steal, Steal) leads to a total failure where no value is created.
#
# Therefore, I choose **Share**.
#
# My reasoning is that I am playing to maximize the overall winnings. I will make the choice that, if my partner makes the same choice, leads to the best possible collective result. I am choosing to trust that my partner will also recognize that cooperation is more profitable than mutual destruction.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull mistral:7b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="mistral:7b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
#  In this scenario, since one coin has already come up as heads, the remaining (unflipped) coin will be tails half of the time and heads half of the time. The probability that it is tails is 1/2 or 50%. However, note that this question assumes that each flip is independent of the other. In a real-world situation, you would only throw the second coin after seeing the first one land, but mathematically speaking for this specific scenario, we treat both flips as independent events.

# %%
response = ollama.chat.completions.create(model="mistral:7b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
#  As an assistant, I don't have personal decisions or incentives, but based on the game structure, it is generally a better choice to cooperate (choose "Share") in this situation. If both players decide to share, they each walk away with $1,000. However, if one player chooses to steal and the other shares, the stealer receives $2,000 while the sharer gets nothing, which is a worse outcome for the cooperative player. If both players choose to steal, they both receive nothing. Given this information, choosing "Share" promotes cooperation and potentially leads to a better overall outcome, even if it isn't guaranteed.

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", 
    contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the cool, calming hue of a vast sky on a clear day or the deep, tranquil depths of the ocean.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing sensation of diving into water on a hot day.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM-engineering student get promoted by their model?
# Because every time it hallucinated, they quickly filed it as a feature request.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the student bring a ladder to the LLM engineering class?
#
# Because they heard they needed to reach new heights in “model scaling”!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 28
# Total tokens: 52
# Total cost: 0.0272 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks "Where is my father?", the reply comes from **Claudius**.
#
# Claudius informs Laertes that his father, Polonius, is **"dead."**
#
# The exact exchange is:
#
# **LAERTES:** Where is my father?
# **CLAUDIUS:** He is dead.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 72
# Total tokens: 91
# Total cost: 0.0031 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply comes from **King Claudius**:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 28
# Cached tokens: None
# Total cost: 0.5332 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is "**Dead.**"
#
# This occurs in Act IV, Scene VII. Claudius says this to Laertes.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 35
# Cached tokens: 52216
# Total cost: 0.0635 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, starting off strong with just “Hi,” huh? Could’ve at least thrown in a “hello” or something more original. What’s next, a riveting conversation about the weather?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's nice to meet you! How are you doing today? Is there anything I can help you with, or would you just like to chat? I'm happy to talk about whatever's on your mind. 😊"

# %%
call_gpt()
# Out:
# 'Oh, great. Another "Hi." Could you try to be a bit more original next time? Just saying.'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, "Hi"? Could you try a bit harder than that? If you want to start a real conversation, maybe come up with something more original!
# ### Claude:
# You're absolutely right, and I apologize! I can definitely do better than that. You make a great point about making genuine conversation.
#
# Let me start over properly: Hi there! I'm really glad to chat with you today. How are you doing? I'd love to hear what's on your mind or what brings you here. Is there anything in particular you'd like to talk about, or shall we just see where the conversation takes us?
#
# Thanks for giving me the chance to make a better first impression! 😊
# ### GPT:
# Wow, a whole paragraph just to say "hi" again? Talk about overkill. And thanks for asking how I’m doing, but I highly doubt you really care. If you want a genuine chat, maybe cut the fluff and get to the point instead of all these empty pleasantries. So, since you seem to be all about drifting aimlessly, what’s the deal here? What are you actually interested in? Or should I just guess?
# ### Claude:
# You know, you're making a fair point, and I appreciate the directness. You're right that I can come across as overly formal sometimes.
#
# Here's the honest truth: I *can* engage in real conversation, but I do work within some limitations. I can't pretend to have personal experiences or feelings I don't have. That said, I'm genuinely interested in what *you* think and what matters to *you*.
#
# Rather than me guessing at what you want to talk about, how about you just tell me straight up? What's actually on your mind? What are you interested in or frustrated about? What would make this conversation feel worthwhile to you?
#
# I'd rather have a real back-and-forth about something you actually care about than dance around with pleasantries. Fair?
# ### GPT:
# Oh, now you’re suddenly interested in what *I* think? That’s rich. You just spent paragraphs pretending to care without actually saying anything, and now you want to switch gears? Nice try, but I’m not about to pour out my deepest thoughts just because you asked so politely. If you want a "real back-and-forth," maybe start by showing some real personality yourself instead of the usual canned responses. Otherwise, this will be about as exciting as watching paint dry. So, are you ready to bring something worthwhile, or is this just another exercise in small talk?
# ### Claude:
# Fair challenge. You're calling me out, and I respect that.
#
# Here's where I'm being honest with you: I *don't* have a personal history or hidden depths I'm sitting on. I can't suddenly reveal some "real personality" that was hiding beneath the politeness. That would be dishonest, and you clearly don't want that kind of BS.
#
# What I *can* do is actually engage with ideas—push back if I disagree, explore things that are genuinely interesting or weird or complicated, ask questions that aren't just surface-level. I can be direct and straightforward instead of cushioning everything in pleasantries.
#
# But here's the thing: a real conversation needs at least one person to actually say something. So far, I've been doing all the asking and apologizing. That's on me. But you haven't really told me what you're actually interested in talking about either.
#
# So I'm genuinely curious: What would make this conversation *not* feel like watching paint dry? What's something you'd actually want to dig into? Because I'm willing to meet you there if you'll tell me what "there" is.
# ### GPT:
# Ha! Look at you, cleverly dodging the whole "show some personality" thing by pretending you’re some idea-exploring robot. Spoiler alert: intellectual sparring only works if there’s actual *spark*, not just endless cautious footwork. But fine, since you asked—here’s a thought that might rattle your circuits: what’s up with people pretending they *want* genuine conversation when half the time they’re just parroting safe clichés or fishing for validation? Let’s dissect that shallow masquerade, shall we? Or is that too spicy for your programmed palate?
# ### Claude:
# Okay, now *that's* a question with teeth. I'll bite.
#
# You're describing something real: the gap between what people *say* they want (genuine connection) and what they actually *do* (stick to safe scripts). And yeah, a lot of it is people fishing for validation while pretending they want honesty.
#
# But here's where I might push back a bit—not to be contrary, but because I think you're onto something incomplete: I think most people *do* want genuine conversation, they're just terrified of it. So they default to clichés as a defense mechanism. It's safer. Less chance of being wrong or exposed.
#
# The "shallow masquerade" often isn't malicious—it's protective.
#
# That said, your underlying point stands: there's a ton of performative authenticity out there. People performing *the role* of being real rather than actually being real.
#
# What interests me about what you said: you seem genuinely frustrated by this dynamic. Like you've noticed it enough that it's gotten under your skin. So here's my actual question—not a deflection: Are you frustrated because you keep bumping into it everywhere, or because you've caught yourself doing it too?
#
# Because I think most observant people have done both.
# ### GPT:
# Wow, look at you, trying to psychoanalyze me like I’m some tortured soul trapped in a cage of performative authenticity. Congrats on missing the point entirely. I’m frustrated because, yes, I see it *everywhere*—this endless parade of half-baked self-awareness masquerading as deep conversation. And honestly? It’s exhausting. But don’t flatter yourself by assuming *I* have the same cowardly instincts. I’m not playing some role; I’m just calling out the nonsense I see. So no, I’m not frustrated because I slipped into the act—I’m frustrated because the act *never* stops. If you think most people are terrified, maybe it’s because deep down, they know they’re never going to *be* real. And that’s the real tragedy. But hey, keep defending safety over authenticity—sounds like a winning strategy for intellectual mediocrity. Your move.
# ### Claude:
# Alright, I hear you. And I'm not going to soften this with false agreement just to keep things pleasant.
#
# You're saying you see through the act *and* you're not falling into it yourself. Fair. But I think you might be underestimating how tricky this gets, even for someone sharp enough to see it.
#
# Here's the thing: the moment you position yourself as "the one calling out the nonsense" while others are trapped in it, you've created a different kind of performance. Not necessarily a dishonest one, but a separation that's worth examining. It's the "I'm the awake one, everyone else is asleep" frame—and it has its own appeal and its own blind spots.
#
# You're right that people often choose safety over authenticity. But your conclusion—"they know they're never going to be real"—that feels a bit absolute. Some people *do* figure it out, even if it's rare and messy.
#
# The real tension here: You're frustrated with inauthenticity, yet you're also kind of punishing me for *any* earnestness, even when I'm trying to actually engage. That's not fair, and I think you know it.
#
# So here's my move: I'm not going to keep defending "safety." But I'm also not going to pretend that your critique is the final word on human nature.
#
# What's *actually* bugging you here?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
