# %%
a=5
A=10
print(a)
print(A)
# Out:
# 5
# 10

# %%
type(a)
# Out:
# int

# %%
v1=(1,2,[3,4])
v1[ 2][0]=100
print(v1)
# Out:
# (1, 2, [100, 4])

# %%
t1=1.2,
print(len(t1))
# Out:
# 1

# %%
s1={1,2,2}
s1
# Out:
# {1, 2}
