# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Hello mars!")
# Out:
# Hello mars!

# %%
cool = "Deep Learning with Python"

# %%
print(cool)
# Out:
# Deep Learning with Python

# %% [markdown]
# # Heading!!!
#
# Hello **world**
