# %%
import pandas as pd

df = pd.read_csv("./data/used_cars.csv")

# %%
price = df["price"]
price = price.str.replace("$", "")
price = price.str.replace(",", "")
price = price.astype(int)

df["price"] = price
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
#
#                                  accident clean_title  price
# 0  At least 1 accident or damage reported         Yes  10300
# 1  At least 1 accident or damage reported         Yes  38005
# 2                           None reported         NaN  54598
# 3                           None reported         Yes  15500
# 4                           None reported         NaN  34999

# %%
df["price"].mean()
# Out:
# np.float64(44553.190321776005)

# %%
df_hyundai = df[df["brand"] == "Hyundai"]
print(df_hyundai["price"].mean())

df_ford = df[df["brand"] == "Ford"]
print(df_ford["price"].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 df_hyundai = df[df["brand"] == "Hyundai"]
# ----> 2 print(df_hyundai["price"].mean())
#       3
#       4 df_ford = df[df["brand"] == "Ford"]
#       5 print(df_ford["price"].mean())
#
# File c:\Users\himan\github\aimonorepo\udeeplearning\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\himan\github\aimonorepo\udeeplearning\.venv\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
#    8071     """
#    8072     Return the mean of the values over the requested axis.
#    8073
#    (...)   8111     2.0
#    8112     """
# -> 8113     return NDFrame.mean(
#    8114         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8115     )
#
# File c:\Users\himan\github\aimonorepo\udeeplearning\.venv\Lib\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11827         skipna: bool = True,
#   11828         numeric_only: bool = False,
#   11829         **kwargs,
#   11830     ) -> Series | float:
# > 11831         return self._stat_function(
#   11832             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833         )
#
# File c:\Users\himan\github\aimonorepo\udeeplearning\.venv\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781         nv.validate_func(name, (), kwargs)
#   11782
#   11783         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11784
# > 11785         return self._reduce(
#   11786             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787         )
#
# File c:\Users\himan\github\aimonorepo\udeeplearning\.venv\Lib\site-packages\pandas\core\series.py:7480, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7476     self._get_axis_number(axis)
#    7478 if isinstance(delegate, ExtensionArray):
#    7479     # dispatch to ExtensionArray interface
# -> 7480     result = delegate._reduce(name, skipna=skipna, **kwds)
#    7482 else:
#    7483     # dispatch to numpy arrays
#    7484     if numeric_only and self.dtype.kind not in "iufcb":
#    7485         # i.e. not is_numeric_dtype(self.dtype)
#
# File c:\Users\himan\github\aimonorepo\udeeplearning\.venv\Lib\site-packages\pandas\core\arrays\string_arrow.py:561, in ArrowStringArray._reduce(self, name, skipna, keepdims, **kwargs)
#     559     result = self._reduce_calc(name, skipna=skipna, keepdims=keepdims, **kwargs)
#     560 else:
# --> 561     raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#     563 if name in ("argmin", "argmax") and isinstance(result, pa.Array):
#     564     return self._convert_int_result(result)
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %%
pd.get_dummies(df["brand"])
# Out:
#       Acura   Alfa  Aston   Audi    BMW  Bentley  Bugatti  Buick  Cadillac  \
# 0     False  False  False  False  False    False    False  False     False
# 1     False  False  False  False  False    False    False  False     False
# 2     False  False  False  False  False    False    False  False     False
# 3     False  False  False  False  False    False    False  False     False
# 4     False  False  False   True  False    False    False  False     False
# ...     ...    ...    ...    ...    ...      ...      ...    ...       ...
# 4004  False  False  False  False  False     True    False  False     False
# 4005  False  False  False   True  False    False    False  False     False
# 4006  False  False  False  False  False    False    False  False     False
# 4007  False  False  False  False  False    False    False  False     False
# 4008  False  False  False  False   True    False    False  False     False
#
#       Chevrolet  ...   Saab  Saturn  Scion  Subaru  Suzuki  Tesla  Toyota  \
# 0         False  ...  False   False  False   False   False  False   False
# 1         False  ...  False   False  False   False   False  False   False
# 2         False  ...  False   False  False   False   False  False   False
# 3         False  ...  False   False  False   False   False  False   False
# 4         False  ...  False   False  False   False   False  False   False
# ...         ...  ...    ...     ...    ...     ...     ...    ...     ...
# 4004      False  ...  False   False  False   False   False  False   False
# 4005      False  ...  False   False  False   False   False  False   False
# 4006      False  ...  False   False  False   False   False  False   False
# 4007      False  ...  False   False  False   False   False  False   False
# 4008      False  ...  False   False  False   False   False  False   False
#
#       Volkswagen  Volvo  smart
# 0          False  False  False
# 1          False  False  False
# 2          False  False  False
# 3          False  False  False
# 4          False  False  False
# ...          ...    ...    ...
# 4004       False  False  False
# 4005       False  False  False
# 4006       False  False  False
# 4007       False  False  False
# 4008       False  False  False
#
# [4009 rows x 57 columns]

# %%
df.head()

# %%
df[["model_year", "price"]].corr()
# Out:
#             model_year     price
# model_year    1.000000  0.199496
# price         0.199496  1.000000

# %%
df2 = pd.DataFrame(data={"model_year": [1, 1, 2], "price": [1, 2, 3]})
print(df2)
df2.corr()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(df["model_year"], df["price"])
plt.show()
